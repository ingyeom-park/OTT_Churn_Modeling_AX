# %%
import pandas as pd

df0 = pd.read_csv(r"C:\myCode\ott-churn-prediction\kim.kwangil\data\260507_merged1_0.csv")
df1 = pd.read_csv(r"C:\myCode\ott-churn-prediction\kim.kwangil\data\260507_merged1_1.csv")
