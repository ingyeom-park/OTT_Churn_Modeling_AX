# %% [markdown]
# # 06f v2 Reduced-Feature Interpretable Baseline Audit
#
# This notebook executes the Stage 06f implementation script. It evaluates fixed diagnostic reduced-feature models for interpretation-safer reporting.

# %%
# %run 06f_v2_reduced_feature_baseline_audit_impl.py
