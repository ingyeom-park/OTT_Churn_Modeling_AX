# %% [markdown]
# # 06e v2 Exact Early-Window Rebuild and Timing-Sensitivity Audit
#
# This notebook executes the Stage 06e implementation script. It rebuilds exact early observation windows from Stage 02 policy outputs and raw view logs, then writes only Stage 06e documentation/audit artifacts.

# %%
# %run 06e_v2_exact_early_window_rebuild_impl.py
