# %% [markdown]
# # 06c3 v2 Corrected Model Benchmark
#
# Runs the corrected strict-core v2c model-family benchmark and limited HPT audit. This notebook writes only Stage 06c3 outputs.

# %%
# %run 06c3_v2_corrected_model_benchmark_impl.py
