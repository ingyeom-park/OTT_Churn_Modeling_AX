# %% [markdown]
# # 07r_v2 TRUE SHAP Interpretation
#
# Purpose: compute true SHAP values in the Python 3.11 environment and supersede the Stage 07 fallback XAI outputs.
#
# Rules: no segmentation, no business simulation, no Optuna, no tuning, no raw modification, no `_data` output, and no Stage 01-07 fallback overwrite.

# %%
from pathlib import Path
import sys

expected = Path(r"C:\Users\Administrator\AppData\Local\Programs\Python\Python311\python.exe").resolve()
actual = Path(sys.executable).resolve()
if actual != expected:
    raise RuntimeError(f"Stage 07r must run with Python 3.11 executable {expected}; got {actual}")

script = Path("07r_v2_true_shap_interpretation_impl.py")
if not script.exists():
    script = Path("park.ingyeom/notebooks/07r_v2_true_shap_interpretation_impl.py")
if not script.exists():
    raise FileNotFoundError("Could not find 07r_v2_true_shap_interpretation_impl.py")

exec(compile(script.read_text(encoding="utf-8"), str(script), "exec"))
# Out:
# 07r_v2 TRUE SHAP interpretation completed.
# raw_files_unchanged: PASS - raw snapshots unchanged
# no_project_root_data_output_created: PASS - Stage 07r writes only under park.ingyeom/reports
# stage01_through_stage07_fallback_outputs_not_overwritten: PASS - Stage 01-07 snapshots unchanged
# shap_import_succeeded: PASS - 0.51.0
# true_shap_values_computed_for_primary_model: PASS - (1819, 166)
# red_blue_shap_beeswarm_created: PASS - classic SHAP summary dot plot
# no_forbidden_feature_used: PASS - violations=0
# target_mapping_documented: PASS - Y=1, N=0
# score_direction_documented: PASS - repurchase_score and churn_risk_score documented
# stage06_split_reused: PASS - park.ingyeom/reports/tables/06_v2_baseline_modeling/06_v2_split_membership_row_ids.csv
# train_test_USER_KEY_overlap_zero: PASS - overlap=0
# model_reconstruction_check_completed: PASS - reconstruction table
# global_shap_table_created: PASS - global SHAP table
# grouped_shap_table_created: PASS - grouped SHAP table
# ...
