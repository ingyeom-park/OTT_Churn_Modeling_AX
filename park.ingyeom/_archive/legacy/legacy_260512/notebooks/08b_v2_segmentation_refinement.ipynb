# %% [markdown]
# # 08b_v2_segmentation_refinement
#
# Purpose: refine Stage 08 segmentation outputs into a smaller, presentation-ready, business-actionable segment set.
#
# Scope: Stage 08b only. No business simulation, no financial impact calculation, no model training, no SHAP run, no Optuna, no raw or legacy modification, and no project-root `_data` outputs.
#
# Inputs: Stage 08 segment assignments and review tables plus Stage 07r TRUE SHAP importance tables.
#
# Outputs: Stage 08b refined assignments, final segment definitions, review decisions, Stage 09 candidate placeholders, team-share summary, figures, markdown report, and final checks.

# %%
import sys
from pathlib import Path

print(sys.executable)
print(sys.version)
assert sys.version_info[:2] == (3, 11), "Stage 08b must run with Python 3.11 for consistency."

def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (
            (candidate / '_data' / '01_raw' / 'Membership.csv').exists()
            and (candidate / 'park.ingyeom' / 'reports' / 'data' / '08_v2_segmentation_strategy' / '08_v2_segmentation_summary.json').exists()
        ):
            return candidate
    raise FileNotFoundError('Could not locate ott-churn-prediction project root.')

PROJECT_ROOT = find_project_root(Path.cwd())
print(PROJECT_ROOT)
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python311\python.exe
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# C:\Code\Github Repository\ott-churn-prediction

# %% [markdown]
# Run the Stage 08b implementation script. The script reads Stage 08 outputs, performs pruning and refinement, writes only Stage 08b outputs, and prints final checks.

# %%
import runpy

impl_path = PROJECT_ROOT / 'park.ingyeom' / 'notebooks' / '08b_v2_segmentation_refinement_impl.py'
runpy.run_path(str(impl_path), run_name='__main__')
# Out:
# 08b_v2 segmentation refinement completed.
# raw_files_unchanged: PASS - raw snapshots unchanged
# no_project_root_data_output_created: PASS - Stage 08b writes only under park.ingyeom/reports
# stage01_through_stage08_outputs_not_overwritten: PASS - Stage 01-08 snapshots unchanged
# stage07r_true_shap_used_as_xai_basis: PASS - 07r TRUE SHAP tables read
# stage07_fallback_not_used_as_final_evidence: PASS - No Stage 07 fallback files read
# is_repurchase_not_used_to_define_segments: PASS - target_used_to_define=False
# forbidden_features_not_used_as_segment_variables: PASS -
# small_n_segments_identified: PASS - early_routine_stable|general_other|week2_surge_users
# high_overlap_segments_identified: PASS - delayed_start|early_routine_stable|genre_affinity_action_adventure|genre_affinity_animation_family|genre_affinity_drama|genre_affinity_thriller_crime|late_heavy_week3_intensive|low_or_no_early_engagement|top_decile_high_churn_risk|week2_surge_users
# ...
