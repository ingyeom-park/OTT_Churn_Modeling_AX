# %% [markdown]
# # 10_v2_final_audit_and_synthesis_check
#
# Purpose: final audit, consistency verification, and presentation-ready synthesis check for the v2 pipeline.
#
# Scope: Stage 10 only. No final deck, no final submission report, no model training, no SHAP run, no Optuna, no new segmentation, no new business simulation, no raw or legacy modification, and no project-root `_data` outputs.
#
# Mode: strict reviewer. Separate facts, model outputs, assumptions, interpretations, recommendations, and prohibited claims.

# %%
import sys
from pathlib import Path

print(sys.executable)
print(sys.version)
assert sys.version_info[:2] == (3, 11), "Stage 10 must run with Python 3.11 for consistency."

def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (
            (candidate / '_data' / '01_raw' / 'Membership.csv').exists()
            and (candidate / 'park.ingyeom' / 'reports' / 'data' / '09_v2_business_simulation' / '09_v2_business_simulation_summary.json').exists()
        ):
            return candidate
    raise FileNotFoundError('Could not locate ott-churn-prediction project root.')

PROJECT_ROOT = find_project_root(Path.cwd())
print(PROJECT_ROOT)
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python311\python.exe
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# C:\Code\Github Repository\ott-churn-prediction

# %% [markdown]
# Run the Stage 10 implementation script. The script reads Stage 01 through Stage 09 outputs, writes only Stage 10 audit artifacts, and prints final checks.

# %%
import runpy

impl_path = PROJECT_ROOT / 'park.ingyeom' / 'notebooks' / '10_v2_final_audit_and_synthesis_check_impl.py'
runpy.run_path(str(impl_path), run_name='__main__')
# Out:
# 10_v2 final audit and synthesis check completed.
# raw_files_unchanged: PASS - raw snapshots unchanged
# no_project_root_data_output_created: PASS - Stage 10 writes only under park.ingyeom/reports
# stage01_through_stage09_outputs_not_overwritten: PASS - Stage 01-09 snapshots unchanged
# all_expected_stage10_outputs_created: PASS - all required outputs exist
# row_count_lineage_created: PASS - lineage table
# key_metric_registry_created: PASS - metric registry
# claim_registry_created: PASS - claim registry
# contradiction_audit_created: PASS - wording audit
# presentation_outline_created: PASS - outline md
# team_handoff_summary_created: PASS - handoff md
# final_issue_register_created: PASS - issue register
# readiness_verdict_created: PASS - verdict md
# stage07r_true_shap_marked_final_xai: PASS - Stage 07r final XAI
# stage07_fallback_marked_audit_only: PASS - Stage 07 fallback audit-only
# stage08b_marked_final_segment_basis: PASS - Stage 08b final segment basis
# ...
