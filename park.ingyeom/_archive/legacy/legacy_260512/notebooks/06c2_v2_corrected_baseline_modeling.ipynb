# %% [markdown]
# # 06c2_v2 Corrected Baseline Modeling
#
# Corrected strict-core baseline and pruned model audit. This notebook executes the paired implementation script and does not run SHAP, Optuna, segmentation, or simulation.

# %%
# %run ./06c2_v2_corrected_baseline_modeling_impl.py
