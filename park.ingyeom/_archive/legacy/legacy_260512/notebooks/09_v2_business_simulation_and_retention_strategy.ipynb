# %% [markdown]
# # 09_v2_business_simulation_and_retention_strategy
#
# Purpose: create scenario-based business simulation and retention action artifacts using Stage 08b final segments.
#
# Scope: Stage 09 only. No model training, no SHAP run, no Optuna, no raw/legacy modification, no project-root `_data` outputs, and no final deck/report generation.
#
# Interpretation: this is not causal proof and not an experiment result. All lift, reach, response, cost, and margin values are assumptions.

# %%
import sys
from pathlib import Path

print(sys.executable)
print(sys.version)
assert sys.version_info[:2] == (3, 11), "Stage 09 must run with Python 3.11 for consistency."

def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (
            (candidate / '_data' / '01_raw' / 'Membership.csv').exists()
            and (candidate / 'park.ingyeom' / 'reports' / 'data' / '08b_v2_segmentation_refinement' / '08b_segmentation_refinement_summary.json').exists()
        ):
            return candidate
    raise FileNotFoundError('Could not locate ott-churn-prediction project root.')

PROJECT_ROOT = find_project_root(Path.cwd())
print(PROJECT_ROOT)
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python311\python.exe
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# C:\Code\Github Repository\ott-churn-prediction

# %% [markdown]
# Run the Stage 09 implementation script. The script writes only Stage 09 outputs and prints final checks.

# %%
import runpy

impl_path = PROJECT_ROOT / 'park.ingyeom' / 'notebooks' / '09_v2_business_simulation_and_retention_strategy_impl.py'
runpy.run_path(str(impl_path), run_name='__main__')
# Out:
# 09_v2 business simulation completed.
# raw_files_unchanged: PASS - raw snapshots unchanged
# no_project_root_data_output_created: PASS - Stage 09 writes only under park.ingyeom/reports
# stage01_through_stage08b_outputs_not_overwritten: PASS - Stage 01-08b snapshots unchanged
# stage07r_true_shap_used_as_xai_basis: PASS - Stage 07r TRUE SHAP tables read
# stage07_fallback_not_used_as_final_evidence: PASS - No Stage 07 fallback files read
# no_model_training_performed: PASS - No model libraries or fit calls used
# no_shap_run: PASS - No shap import or computation used
# no_optuna_run: PASS - No Optuna import or tuning used
# no_segmentation_redefinition_beyond_stage08b_final_segments: PASS - genre_affinity_content_recommendation_pool|late_week3_engaged_retention_candidate|low_risk_or_general_maintenance|risk_10_30_low_engagement|risk_10_30_other_review|top_decile_high_churn_risk
# ...
