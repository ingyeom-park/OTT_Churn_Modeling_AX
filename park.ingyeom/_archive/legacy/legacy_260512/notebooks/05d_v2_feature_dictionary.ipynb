# %% [markdown]
# # 05d v2 Feature Dictionary
#
# Team-sharing feature dictionary. Documentation only. No model training, no SHAP run, no Optuna, no new features.

# %%
# %run 05d_v2_feature_dictionary_impl.py
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File C:\Code\ott-churn-prediction\park.ingyeom\notebooks\05d_v2_feature_dictionary_impl.py:644
#     627 sheets = {
#     628     "README": readme,
#     629     "all_columns_dictionary": all_columns_dictionary,
#    (...)
#     640     "data_type_audit": data_type_audit,
#     641 }
#     643 for sheet, df in sheets.items():
# --> 644     write_csv(sheet, df)
#     646 raw_after_pre = snapshot_files(RAW_FILES)
#     647 data_after_pre = snapshot_tree([PROJECT_ROOT / "_data"])
#
# File C:\Code\ott-churn-prediction\park.ingyeom\notebooks\05d_v2_feature_dictionary_impl.py:145, in write_csv(name, df)
#     144 def write_csv(name, df):
# --> 145     df.to_csv(OUT_TABLE / f"05d_{name}.csv", index=False, encoding="utf-8-sig")
#
# ...
