# %% [markdown]
# # 05e v2 Final Feature Pruning Policy
#
# Executes the final feature pruning policy and creates separate pruned modeling datasets.

# %%
# %run 05e_v2_final_feature_pruning_policy_impl.py
