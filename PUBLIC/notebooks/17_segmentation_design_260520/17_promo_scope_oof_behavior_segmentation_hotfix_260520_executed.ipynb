# %% [markdown]
# # PUBLIC 17 semantic hotfix
# Reads existing 17 outputs and creates semantic hotfix artifacts only.

# %%
from pathlib import Path
import sys

cwd = Path.cwd().resolve()
repo_root = cwd
for candidate in [cwd, *cwd.parents]:
    if (candidate / 'PUBLIC').exists():
        repo_root = candidate
        break
helper_dir = repo_root / 'PUBLIC' / 'handoff' / 'PUBLIC_17_segmentation_semantic_hotfix_260520'
sys.path.insert(0, str(helper_dir))

from public_17_semantic_hotfix_runner import run_all

result = run_all(executed_from_notebook=True)
result
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\zipfile.py:1506: UserWarning: Duplicate name: 'PUBLIC/results/17_segmentation_design_260520/promo_scope_oof_behavior_segments_hotfix_260520/17_hotfix_revalidation_passes.csv'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# {'output_dir': 'PUBLIC\\results\\17_segmentation_design_260520\\promo_scope_oof_behavior_segments_hotfix_260520',
#  'content_preference_broad': True,
#  'rows': 23097,
#  'executed_from_notebook': True}
