# %% [markdown]
# # PUBLIC 15 OOF Score Hotfix 260520
#
# Executes the local hotfix helper. No Optuna, SHAP, segmentation, or final model selection is performed.

# %%
from pathlib import Path
import sys
repo = Path(r'C:/Code/ott-churn-prediction')
helper_dir = repo / 'PUBLIC' / 'handoff' / 'PUBLIC_15_oof_score_hotfix_260520'
sys.path.insert(0, str(helper_dir))
from public_15_oof_hotfix_runner import run_hotfix
result = run_hotfix(executed_from_notebook=True)
print(result)
# Out:
# {'inventory': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\handoff\\PUBLIC_15_oof_score_hotfix_260520\\15_existing_oof_inventory_before_hotfix.csv', 'artifact_validation': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\handoff\\PUBLIC_15_oof_score_hotfix_260520\\15_existing_oof_artifact_validation.csv', 'input_validation': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\handoff\\PUBLIC_15_oof_score_hotfix_260520\\15_oof_hotfix_input_validation.csv', 'feature_policy': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\results\\15_oof_score_or_sensitivity_260520\\four_model_oof_scores_hotfix_260520\\15_oof_feature_policy_check.csv', 'split_policy': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\results\\15_oof_score_or_sensitivity_260520\\four_model_oof_scores_hotfix_260520\\15_oof_split_policy_check.csv', 'model_config': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\results\\15_oof_score_or_sensitivity_260520\\four_model_oof_scores_hotfix_260520\\15_model_config_extraction.csv', 'oof_long_rows': 46194, 'oof_wide_rows': 23097, 'overlap': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\results\\15_oof_score_or_sensitivity_260520\\four_model_oof_scores_hotfix_260520\\15_gb_lr_high_risk_overlap.csv', 'readiness': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\results\\15_oof_score_or_sensitivity_260520\\four_model_oof_scores_hotfix_260520\\15_oof_readiness_for_shap_segmentation.csv', 'fingerprint': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\handoff\\PUBLIC_15_oof_score_hotfix_260520\\15_source_fingerprint_before_after.csv', 'readme': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\results\\15_oof_score_or_sensitivity_260520\\four_model_oof_scores_hotfix_260520\\README.md', 'handoff': 'C:\\Code\\ott-churn-prediction\\PUBLIC\\handoff\\PUBLIC_15_oof_score_hotfix_260520\\README.md', 'executed_from_notebook': True}
