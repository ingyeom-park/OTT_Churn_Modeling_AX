# %% [markdown]
# # 06z_gb_promo1_logretention_only
#
# Prepared notebook for log retention only model rerun. This notebook is generated for manual/team execution and was not executed during the prep goal.

# %% [markdown]
# ## Scope
#
# - Raw retention columns are forbidden.
# - `log_retention_w2_ratio` and `log_retention_w3_ratio` must be features.
# - `is_repurchase`, `USER_KEY`, `is_promotion`, and payment indicator columns are excluded from features.
# - StratifiedKFold is used for comparability with existing PUBLIC notebooks. USER_KEY duplicate group leakage caveat remains.

# %%
from pathlib import Path
import json
import warnings

import numpy as np
import optuna
import pandas as pd
from sklearn.metrics import average_precision_score, f1_score, precision_score, recall_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.ensemble import GradientBoostingClassifier

warnings.filterwarnings("ignore", category=UserWarning)

ROOT = Path.cwd()
if not (ROOT / "PUBLIC").exists():
    ROOT = Path(r"C:\Users\USER\OneDrive\바탕 화면\AX git\ott-churn-prediction")
PUBLIC = ROOT / "PUBLIC"

DATA = ROOT / "PUBLIC/data/06z_model_input_promo_1_log_retention_only.csv"
OUT_DIR = ROOT / "PUBLIC/results/_06z_log_retention_only_model_rerun_260520/gb_promo1"
PROMO = 1
MODEL_NAME = "GradientBoostingClassifier conservative"
RANDOM_STATE = 42
N_TRIALS = 100
N_SPLITS = 5
OVERFIT_GAP = 0.03
TEST_SIZE = 0.2
GAP_PENALTY = 0.50

TARGET_COL = "is_repurchase"
ID_COL = "USER_KEY"
RAW_RETENTION_COLS = ["retention_w2_ratio", "retention_w3_ratio"]
LOG_RETENTION_COLS = ["log_retention_w2_ratio", "log_retention_w3_ratio"]
EXCLUDE_COLS = [
    TARGET_COL,
    ID_COL,
    "is_promotion",
    "payment_is_mobile",
    "payment_is_pc",
    "payment_is_android",
    "payment_is_ios",
] + RAW_RETENTION_COLS

OUT_DIR.mkdir(parents=True, exist_ok=True)

df = pd.read_csv(DATA)
if any(col in df.columns for col in RAW_RETENTION_COLS):
    raise ValueError("Raw retention columns must not exist in log retention only model input.")
missing_log = [col for col in LOG_RETENTION_COLS if col not in df.columns]
if missing_log:
    raise ValueError(f"Missing log retention columns: {missing_log}")
if TARGET_COL not in df.columns:
    raise ValueError("Missing target column is_repurchase.")

feature_cols = [col for col in df.columns if col not in EXCLUDE_COLS]
non_numeric_cols = df[feature_cols].select_dtypes(exclude="number").columns.tolist()
if non_numeric_cols:
    raise ValueError(f"Non-numeric feature columns found: {non_numeric_cols}")
if not set(LOG_RETENTION_COLS).issubset(feature_cols):
    raise ValueError("Log retention columns are not included as features.")

X = df[feature_cols].copy()
y = pd.to_numeric(df[TARGET_COL], errors="raise").astype(int)
missing_total = int(X.isna().sum().sum())
if missing_total:
    X = X.fillna(X.median(numeric_only=True))

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y,
)

def make_model(params):
    return GradientBoostingClassifier(**params)

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 250),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.05),
        "max_depth": trial.suggest_int("max_depth", 1, 3),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 50, 300),
        "min_samples_split": trial.suggest_int("min_samples_split", 100, 600),
        "subsample": trial.suggest_float("subsample", 0.60, 0.90),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", None]),
        "random_state": RANDOM_STATE,
    }

    cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
    train_scores = []
    valid_scores = []
    for train_idx, valid_idx in cv.split(X_train, y_train):
        X_tr = X_train.iloc[train_idx]
        X_va = X_train.iloc[valid_idx]
        y_tr = y_train.iloc[train_idx]
        y_va = y_train.iloc[valid_idx]
        model = make_model(params)
        model.fit(X_tr, y_tr)
        train_pred = model.predict_proba(X_tr)[:, 1]
        valid_pred = model.predict_proba(X_va)[:, 1]
        train_scores.append(roc_auc_score(y_tr, train_pred))
        valid_scores.append(roc_auc_score(y_va, valid_pred))
    mean_train_auc = float(np.mean(train_scores))
    mean_valid_auc = float(np.mean(valid_scores))
    gap = mean_train_auc - mean_valid_auc
    objective_value = mean_valid_auc - GAP_PENALTY * max(0.0, gap)
    trial.set_user_attr("mean_train_auc", mean_train_auc)
    trial.set_user_attr("mean_valid_auc", mean_valid_auc)
    trial.set_user_attr("gap", gap)
    trial.set_user_attr("overfit", bool(gap > OVERFIT_GAP))
    trial.set_user_attr("objective_value", objective_value)
    return objective_value

study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(objective, n_trials=N_TRIALS)

trial_rows = []
for trial in study.trials:
    row = {
        "trial": trial.number,
        "objective_value": trial.user_attrs.get("objective_value"),
        "mean_valid_auc": trial.user_attrs.get("mean_valid_auc"),
        "mean_train_auc": trial.user_attrs.get("mean_train_auc"),
        "gap": trial.user_attrs.get("gap"),
        "overfit": trial.user_attrs.get("overfit"),
    }
    for key, value in trial.params.items():
        row[f"param_{key}"] = value
    trial_rows.append(row)
trials = pd.DataFrame(trial_rows)
trials.to_csv(OUT_DIR / "trials_all.csv", index=False, encoding="utf-8-sig")

eligible = trials[trials["overfit"].eq(False)].copy()
if eligible.empty:
    selected = trials.sort_values(["objective_value", "mean_valid_auc"], ascending=False).iloc[0]
    selection_note = "WARN: no non-overfit trial found"
else:
    selected = eligible.sort_values(["objective_value", "mean_valid_auc"], ascending=False).iloc[0]
    selection_note = "PASS: selected best non-overfit trial"

best_trial = study.trials[int(selected["trial"])]
best_params = best_trial.params
model = make_model(best_params)
model.fit(X_train, y_train)
test_proba = model.predict_proba(X_test)[:, 1]
test_pred = (test_proba >= 0.5).astype(int)
train_proba = model.predict_proba(X_train)[:, 1]

final_train_auc = roc_auc_score(y_train, train_proba)
test_roc_auc = roc_auc_score(y_test, test_proba)
test_pr_auc = average_precision_score(y_test, test_proba)

final = {
    "model": MODEL_NAME,
    "promo": PROMO,
    "data_file": str(DATA),
    "n_rows": len(df),
    "n_features": len(feature_cols),
    "n_trials": N_TRIALS,
    "best_trial": int(selected["trial"]),
    "gap_penalty": GAP_PENALTY,
    "best_objective_value": float(selected["objective_value"]),
    "best_valid_auc": float(selected["mean_valid_auc"]),
    "best_train_auc": float(selected["mean_train_auc"]),
    "best_gap": float(selected["gap"]),
    "overfit": bool(selected["overfit"]),
    "test_roc_auc": float(test_roc_auc),
    "test_pr_auc": float(test_pr_auc),
    "test_f1": float(f1_score(y_test, test_pred)),
    "test_precision": float(precision_score(y_test, test_pred, zero_division=0)),
    "test_recall": float(recall_score(y_test, test_pred, zero_division=0)),
    "final_train_auc": float(final_train_auc),
    "final_gap_proxy": float(final_train_auc - test_roc_auc),
    "selection_note": selection_note,
    "cv_method": "StratifiedKFold",
    "group_leakage_caveat": "USER_KEY can be duplicated. StratifiedKFold is retained for comparability with PUBLIC notebooks; GroupKFold was not used in this prepared notebook.",
    "raw_retention_removed": True,
    "log_retention_used": True,
}
for key, value in best_params.items():
    final[f"param_{key}"] = value
pd.DataFrame([final]).to_csv(OUT_DIR / "final_result.csv", index=False, encoding="utf-8-sig")

feature_manifest = pd.DataFrame({
    "feature_name": feature_cols,
    "used_as_feature": True,
})
feature_manifest.to_csv(OUT_DIR / "feature_manifest_used.csv", index=False, encoding="utf-8-sig")

print(json.dumps(final, ensure_ascii=False, indent=2))
# Out:
# [I 2026-05-20 14:55:22,013] A new study created in memory with name: no-name-0d38b02e-4872-4590-ba80-704bef40c9e2
# [I 2026-05-20 14:55:45,472] Trial 0 finished with value: 0.8417183478410143 and parameters: {'n_estimators': 125, 'learning_rate': 0.04802857225639665, 'max_depth': 3, 'min_samples_leaf': 200, 'min_samples_split': 178, 'subsample': 0.6467983561008608, 'max_features': None}. Best is trial 0 with value: 0.8417183478410143.
# [I 2026-05-20 14:55:57,426] Trial 1 finished with value: 0.8087686372647112 and parameters: {'n_estimators': 170, 'learning_rate': 0.03832290311184182, 'max_depth': 1, 'min_samples_leaf': 293, 'min_samples_split': 517, 'subsample': 0.6637017332034828, 'max_features': None}. Best is trial 0 with value: 0.8417183478410143.
# [I 2026-05-20 14:56:10,617] Trial 2 finished with value: 0.8161256751717926 and parameters: {'n_estimators': 111, 'learning_rate': 0.030990257265289513, 'max_depth': 2, 'min_samples_leaf': 123, 'min_samples_split': 406, 'subsample': 0.6418481581956126, 'max_features': None}. Best is trial 0 with value: 0.8417183478410143.
# [I 2026-05-20 14:56:12,735] Trial 3 finished with value: 0.7957690132261286 and parameters: {'n_estimators': 141, 'learning_rate': 0.041407038455720545, 'max_depth': 1, 'min_samples_leaf': 179, 'min_samples_split': 396, 'subsample': 0.6139351238159994, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8417183478410143.
# [I 2026-05-20 14:56:14,605] Trial 4 finished with value: 0.8210223648174468 and parameters: {'n_estimators': 63, 'learning_rate': 0.047955421490133335, 'max_depth': 3, 'min_samples_leaf': 252, 'min_samples_split': 252, 'subsample': 0.6293016342019151, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8417183478410143.
# [I 2026-05-20 14:56:20,237] Trial 5 finished with value: 0.7694112601194658 and parameters: {'n_estimators': 74, 'learning_rate': 0.029807076404450808, 'max_depth': 1, 'min_samples_leaf': 278, 'min_samples_split': 229, 'subsample': 0.7987566853061946, 'max_features': None}. Best is trial 0 with value: 0.8417183478410143.
# [I 2026-05-20 14:56:54,442] Trial 6 finished with value: 0.8277725628009263 and parameters: {'n_estimators': 159, 'learning_rate': 0.017394178221021083, 'max_depth': 3, 'min_samples_leaf': 244, 'min_samples_split': 570, 'subsample': 0.8684482051282947, 'max_features': None}. Best is trial 0 with value: 0.8417183478410143.
# [I 2026-05-20 14:56:55,497] Trial 7 finished with value: 0.7512020273637678 and parameters: {'n_estimators': 67, 'learning_rate': 0.017839314496765808, 'max_depth': 1, 'min_samples_leaf': 131, 'min_samples_split': 294, 'subsample': 0.6814047095321688, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8417183478410143.
# [I 2026-05-20 14:56
 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:21:17,466] Trial 44 finished with value: 0.8456814445304692 and parameters: {'n_estimators': 215, 'learning_rate': 0.03830096536928697, 'max_depth': 3, 'min_samples_leaf': 193, 'min_samples_split': 561, 'subsample': 0.6694990946882104, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:21:21,104] Trial 45 finished with value: 0.8119911712395425 and parameters: {'n_estimators': 217, 'learning_rate': 0.041956906981012385, 'max_depth': 1, 'min_samples_leaf': 190, 'min_samples_split': 566, 'subsample': 0.6738204844056626, 'max_features': 'sqrt'}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:21:47,435] Trial 46 finished with value: 0.8418341613040174 and parameters: {'n_estimators': 141, 'learning_rate': 0.03855679708288287, 'max_depth': 3, 'min_samples_leaf': 98, 'min_samples_split': 554, 'subsample': 0.6933116939610473, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:22:28,152] Trial 47 finished with value: 0.8461462787260207 and parameters: {'n_estimators': 240, 'learning_rate': 0.04288683244422545, 'max_depth': 3, 'min_samples_leaf': 128, 'min_samples_split': 512, 'subsample': 0.6267432140912679, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:23:06,790] Trial 48 finished with value: 0.8456287127292417 and parameters: {'n_estimators': 223, 'learning_rate': 0.0430742689100094, 'max_depth': 3, 'min_samples_leaf': 109, 'min_samples_split': 595, 'subsample': 0.6192533829091598, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:24:14,511] Trial 49 finished with value: 0.8457287735409384 and parameters: {'n_estimators': 250, 'learning_rate': 0.037711771029999536, 'max_depth': 3, 'min_samples_leaf': 231, 'min_samples_split': 509, 'subsample': 0.635987324552394, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:24:26,713] Trial 50 finished with value: 0.8435088378822302 and parameters: {'n_estimators': 250, 'learning_rate': 0.040176383275434234, 'max_depth': 3, 'min_samples_leaf': 240, 'min_samples_split': 498, 'subsample': 0.6320796397754497, 'max_features': 'sqrt'}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:25:31,591] Trial 51 finished with value: 0.8446290825210523 and parameters: {'n_estimators': 242, 'learning_rate': 0.037635173925103266, 'max_depth': 3, 'min_samples_leaf': 289, 'min_samples_split': 551, 'subsample': 0.6084196799701662, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:26:35,963] Trial 52 finished with value: 0.845376514298997 and parameters: {'n_estimators': 209, 'learning_rate': 0.041366132475204126, 'max_depth': 3, 'min_samples_leaf': 267, 'min_samples_split': 512, 'subsample': 0.6475948407308514, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:27:32,209] Trial 53 finished with value: 0.8442827467717842 and parameters: {'n_estimators': 199, 'learning_rate': 0.04307825193800476, 'max_depth': 3, 'min_samples_leaf': 229, 'min_samples_split': 481, 'subsample': 0.62005799682935, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:28:45,723] Trial 54 finished with value: 0.8267424802594474 and parameters: {'n_estimators': 226, 'learning_rate': 0.011474379762345756, 'max_depth': 3, 'min_samples_leaf': 200, 'min_samples_split': 515, 'subsample': 0.6624028704028129, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:30:03,621] Trial 55 finished with value: 0.8454469632199075 and parameters: {'n_estimators': 240, 'learning_rate': 0.03741768058440876, 'max_depth': 3, 'min_samples_leaf': 183, 'min_samples_split': 475, 'subsample': 0.6368038009156827, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:31:17,069] Trial 56 finished with value: 0.8467489522116101 and parameters: {'n_estimators': 213, 'learning_rate': 0.044007150501973416, 'max_depth': 3, 'min_samples_leaf': 152, 'min_samples_split': 429, 'subsample': 0.6666216978987896, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:32:34,984] Trial 57 finished with value: 0.8445963922348861 and parameters: {'n_estimators': 241, 'learning_rate': 0.04415629189470381, 'max_depth': 3, 'min_samples_leaf': 153, 'min_samples_split': 412, 'subsample': 0.6254007242503208, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:33:07,629] Trial 58 finished with value: 0.8240880920552666 and parameters: {'n_estimators': 250, 'learning_rate': 0.04674364132162197, 'max_depth': 1, 'min_samples_leaf': 135, 'min_samples_split': 426, 'subsample': 0.6472745585716534, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:34:23,990] Trial 59 finished with value: 0.8456126218300446 and parameters: {'n_estimators': 225, 'learning_rate': 0.04100088792709444, 'max_depth': 3, 'min_samples_leaf': 159, 'min_samples_split': 378, 'subsample': 0.68228219255337, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:35:49,632] Trial 60 finished with value: 0.8462419447837217 and parameters: {'n_estimators': 237, 'learning_rate': 0.04451983726872405, 'max_depth': 3, 'min_samples_leaf': 147, 'min_samples_split': 433, 'subsample': 0.7067654864424406, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:37:16,523] Trial 61 finished with value: 0.845631016815704 and parameters: {'n_estimators': 237, 'learning_rate': 0.04407501753842375, 'max_depth': 3, 'min_samples_leaf': 147, 'min_samples_split': 468, 'subsample': 0.704071815068836, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:38:42,811] Trial 62 finished with value: 0.8453172013671133 and parameters: {'n_estimators': 245, 'learning_rate': 0.04828591494605892, 'max_depth': 3, 'min_samples_leaf': 134, 'min_samples_split': 432, 'subsample': 0.6862588302379995, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:40:03,390] Trial 63 finished with value: 0.8461113149964359 and parameters: {'n_estimators': 228, 'learning_rate': 0.0467980894034958, 'max_depth': 3, 'min_samples_leaf': 152, 'min_samples_split': 497, 'subsample': 0.6577087118250083, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:44:54,196] Trial 64 finished with value: 0.846331268499715 and parameters: {'n_estimators': 211, 'learning_rate': 0.046722578909206516, 'max_depth': 3, 'min_samples_leaf': 148, 'min_samples_split': 403, 'subsample': 0.66377356883449, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:45:32,176] Trial 65 finished with value: 0.845593817905915 and parameters: {'n_estimators': 213, 'learning_rate': 0.04653817762244344, 'max_depth': 3, 'min_samples_leaf': 150, 'min_samples_split': 392, 'subsample': 0.6625012598882642, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:46:11,932] Trial 66 finished with value: 0.8464838991273169 and parameters: {'n_estimators': 220, 'learning_rate': 0.04809430728790466, 'max_depth': 3, 'min_samples_leaf': 141, 'min_samples_split': 442, 'subsample': 0.6724055954461005, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:46:47,087] Trial 67 finished with value: 0.845141763894022 and parameters: {'n_estimators': 199, 'learning_rate': 0.04796387606784263, 'max_depth': 3, 'min_samples_leaf': 120, 'min_samples_split': 444, 'subsample': 0.6549153599445462, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:47:16,643] Trial 68 finished with value: 0.8427781331783344 and parameters: {'n_estimators': 219, 'learning_rate': 0.04530366781912967, 'max_depth': 2, 'min_samples_leaf': 142, 'min_samples_split': 406, 'subsample': 0.6714313963058903, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:47:28,414] Trial 69 finished with value: 0.8427910421936763 and parameters: {'n_estimators': 210, 'learning_rate': 0.04727273944660777, 'max_depth': 3, 'min_samples_leaf': 165, 'min_samples_split': 374, 'subsample': 0.6410663126757226, 'max_features': 'sqrt'}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:48:30,970] Trial 70 finished with value: 0.8450092042570496 and parameters: {'n_estimators': 202, 'learning_rate': 0.04873280591707477, 'max_depth': 3, 'min_samples_leaf': 139, 'min_samples_split': 493, 'subsample': 0.6119310908408647, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:49:47,070] Trial 71 finished with value: 0.8450423517106171 and parameters: {'n_estimators': 229, 'learning_rate': 0.04584939229719459, 'max_depth': 3, 'min_samples_leaf': 128, 'min_samples_split': 468, 'subsample': 0.7086205928598136, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:50:43,897] Trial 72 finished with value: 0.8452785590471013 and parameters: {'n_estimators': 192, 'learning_rate': 0.04305611743429202, 'max_depth': 3, 'min_samples_leaf': 110, 'min_samples_split': 434, 'subsample': 0.6668090723562136, 'max_features': None}. Best is trial 34 with value: 0.8469379265761374.
# [I 2026-05-20 15:51:58,877] Trial 73 finished with value: 0.847072626120448 and parameters: {'n_estimators': 227, 'learning_rate': 0.04454296982404097, 'max_depth': 3, 'min_samples_leaf': 157, 'min_samples_split': 526, 'subsample': 0.6780016975799442, 'max_features': None}. Best is trial 73 with value: 0.847072626120448.
# [I 2026-05-20 15:53:11,917] Trial 74 finished with value: 0.8469698775552449 and parameters: {'n_estimators': 228, 'learning_rate': 0.044605505572399125, 'max_depth': 3, 'min_samples_leaf': 157, 'min_samples_split': 544, 'subsample': 0.6805471015485939, 'max_features': None}. Best is trial 73 with value: 0.847072626120448.
# [I 2026-05-20 15:54:24,841] Trial 75 finished with value: 0.8467630172442002 and parameters: {'n_estimators': 223, 'learning_rate': 0.04461105771883147, 'max_depth': 3, 'min_samples_leaf': 159, 'min_samples_split': 580, 'subsample': 0.6788082658459123, 'max_features': None}. Best is trial 73 with value: 0.847072626120448.
# [I 2026-05-20 15:55:36,025] Trial 76 finished with value: 0.8473700476053769 and parameters: {'n_estimators': 219, 'learning_rate': 0.04455184574641063, 'max_depth': 3, 'min_samples_leaf': 176, 'min_samples_split': 542, 'subsample': 0.6772458600812739, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 15:56:39,160] Trial 77 finished with value: 0.8470948553931995 and parameters: {'n_estimators': 221, 'learning_rate': 0.045737834549213326, 'max_depth': 3, 'min_samples_leaf': 177, 'min_samples_split': 579, 'subsample': 0.6773971059324614, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 15:57:21,592] Trial 78 finished with value: 0.8435855105961654 and parameters: {'n_estimators': 223, 'learning_rate': 0.04538119539900546, 'max_depth': 2, 'min_samples_leaf': 182, 'min_samples_split': 580, 'subsample': 0.6879527511702406, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 15:58:29,770] Trial 79 finished with value: 0.8460325431449102 and parameters: {'n_estimators': 219, 'learning_rate': 0.04854441702700714, 'max_depth': 3, 'min_samples_leaf': 162, 'min_samples_split': 543, 'subsample': 0.7265579095724963, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 15:59:12,620] Trial 80 finished with value: 0.8454553333572351 and parameters: {'n_estimators': 180, 'learning_rate': 0.042073557694049815, 'max_depth': 3, 'min_samples_leaf': 176, 'min_samples_split': 576, 'subsample': 0.6799235902818165, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 15:59:49,236] Trial 81 finished with value: 0.8468068720997538 and parameters: {'n_estimators': 205, 'learning_rate': 0.04604626338302214, 'max_depth': 3, 'min_samples_leaf': 157, 'min_samples_split': 533, 'subsample': 0.6752539795927517, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:00:37,726] Trial 82 finished with value: 0.8464350430731237 and parameters: {'n_estimators': 206, 'learning_rate': 0.044070339756339505, 'max_depth': 3, 'min_samples_leaf': 157, 'min_samples_split': 541, 'subsample': 0.6756979027740039, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:01:52,845] Trial 83 finished with value: 0.8461624687258695 and parameters: {'n_estimators': 215, 'learning_rate': 0.04929165858883954, 'max_depth': 3, 'min_samples_leaf': 178, 'min_samples_split': 527, 'subsample': 0.6998342495475073, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:02:59,165] Trial 84 finished with value: 0.8459117210820146 and parameters: {'n_estimators': 193, 'learning_rate': 0.04564433222180689, 'max_depth': 3, 'min_samples_leaf': 165, 'min_samples_split': 589, 'subsample': 0.6756476100914222, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:04:09,751] Trial 85 finished with value: 0.846578874215427 and parameters: {'n_estimators': 232, 'learning_rate': 0.04767188002064634, 'max_depth': 3, 'min_samples_leaf': 189, 'min_samples_split': 562, 'subsample': 0.6857990149774515, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:04:22,798] Trial 86 finished with value: 0.8430283764591858 and parameters: {'n_estimators': 233, 'learning_rate': 0.03912088625631737, 'max_depth': 3, 'min_samples_leaf': 188, 'min_samples_split': 554, 'subsample': 0.7127440839754803, 'max_features': 'sqrt'}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:04:56,180] Trial 87 finished with value: 0.8389599167698127 and parameters: {'n_estimators': 104, 'learning_rate': 0.043519579325150486, 'max_depth': 3, 'min_samples_leaf': 205, 'min_samples_split': 565, 'subsample': 0.6890870947812695, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:06:25,469] Trial 88 finished with value: 0.8443530942528215 and parameters: {'n_estimators': 229, 'learning_rate': 0.04491391399479565, 'max_depth': 3, 'min_samples_leaf': 173, 'min_samples_split': 598, 'subsample': 0.8862988210836256, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:07:45,092] Trial 89 finished with value: 0.8454965869723473 and parameters: {'n_estimators': 205, 'learning_rate': 0.04225947906346238, 'max_depth': 3, 'min_samples_leaf': 197, 'min_samples_split': 525, 'subsample': 0.7432687669363858, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:08:04,503] Trial 90 finished with value: 0.8213927453632484 and parameters: {'n_estimators': 224, 'learning_rate': 0.04734149491582749, 'max_depth': 1, 'min_samples_leaf': 170, 'min_samples_split': 580, 'subsample': 0.6829468940540017, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:08:56,513] Trial 91 finished with value: 0.8463521251208923 and parameters: {'n_estimators': 220, 'learning_rate': 0.047803651274682696, 'max_depth': 3, 'min_samples_leaf': 158, 'min_samples_split': 545, 'subsample': 0.6696249896446768, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:10:02,415] Trial 92 finished with value: 0.8460180798712549 and parameters: {'n_estimators': 234, 'learning_rate': 0.046022509175977416, 'max_depth': 3, 'min_samples_leaf': 139, 'min_samples_split': 562, 'subsample': 0.6494692749038474, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:10:58,725] Trial 93 finished with value: 0.8459899100261017 and parameters: {'n_estimators': 212, 'learning_rate': 0.049629406771813066, 'max_depth': 3, 'min_samples_leaf': 166, 'min_samples_split': 530, 'subsample': 0.6544615482899756, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:11:44,754] Trial 94 finished with value: 0.8459354660326392 and parameters: {'n_estimators': 186, 'learning_rate': 0.04609399260873406, 'max_depth': 3, 'min_samples_leaf': 186, 'min_samples_split': 554, 'subsample': 0.666463805751709, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:12:40,168] Trial 95 finished with value: 0.847128517922916 and parameters: {'n_estimators': 220, 'learning_rate': 0.044628408171072026, 'max_depth': 3, 'min_samples_leaf': 178, 'min_samples_split': 572, 'subsample': 0.6960681762851787, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:13:01,283] Trial 96 finished with value: 0.8342289964263785 and parameters: {'n_estimators': 82, 'learning_rate': 0.044434872511567636, 'max_depth': 3, 'min_samples_leaf': 179, 'min_samples_split': 575, 'subsample': 0.6970890063478246, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:13:59,118] Trial 97 finished with value: 0.839935289341835 and parameters: {'n_estimators': 231, 'learning_rate': 0.021690912806131436, 'max_depth': 3, 'min_samples_leaf': 158, 'min_samples_split': 539, 'subsample': 0.684958545885506, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:14:28,423] Trial 98 finished with value: 0.8391971093050941 and parameters: {'n_estimators': 121, 'learning_rate': 0.04044729332763999, 'max_depth': 3, 'min_samples_leaf': 175, 'min_samples_split': 521, 'subsample': 0.66049534686581, 'max_features': None}. Best is trial 76 with value: 0.8473700476053769.
# [I 2026-05-20 16:14:37,563] Trial 99 finished with value: 0.8418921551520367 and parameters: {'n_estimators': 202, 'learning_rate': 0.043585785407526036, 'max_depth': 3, 'min_samples_leaf': 192, 'min_samples_split': 588, 'subsample': 0.6770138248641999, 'max_features': 'sqrt'}. Best is trial 76 with value: 0.8473700476053769.
# {
#   "model": "GradientBoostingClassifier conservative",
#   "promo": 1,
#   "data_file": "C:\\Users\\USER\\OneDrive\\바탕 화면\\AX git\\ott-churn-prediction\\PUBLIC\\data\\06z_model_input_promo_1_log_retention_only.csv",
#   "n_rows": 11904,
#   "n_features": 75,
#   "n_trials": 100,
#   "best_trial": 76,
#   "gap_penalty": 0.5,
#   "best_objective_value": 0.8473700476053769,
#   "best_valid_auc": 0.8594882300706228,
#   "best_train_auc": 0.8837245950011144,
#   "best_gap": 0.02423636493049164,
#   "overfit": false,
#   "test_roc_auc": 0.862128957412163,
#   "test_pr_auc": 0.9280823088762329,
#   "test_f1": 0.8527498521584861,
#   "test_precision": 0.8128523111612176,
#   "test_recall": 0.8967661691542289,
#   "final_train_auc": 0.8813762843160884,
#   "final_gap_proxy": 0.019247326903925388,
#   "selection_note": "PASS: selected best non-overfit trial",
#   "cv_method": "StratifiedKFold",
#   "group_leakage_caveat": "USER_KEY can be duplicated. StratifiedKFold is retained for comparability with PUBLIC notebooks; GroupKFold was not used in this prepared notebook.",
#   "raw_retention_removed": true,
#   "log_retention_used": true,
#   "param_n_estimators": 219,
#   "param_learning_rate": 0.04455184574641063,
#   "param_max_depth": 3,
#   "param_min_samples_leaf": 176,
#   "param_min_samples_split": 542,
#   "param_subsample": 0.6772458600812739,
#   "param_max_features": null
# }
