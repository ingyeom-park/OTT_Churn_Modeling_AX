# %% [markdown]
# # 06z_gb_promo0_logretention_only
#
# Prepared notebook for log retention only model rerun. This notebook is generated for manual/team execution and was not executed during the prep goal.

# %% [markdown]
# ## Scope
#
# - Raw retention columns are forbidden.
# - `log_retention_w2_ratio` and `log_retention_w3_ratio` must be features.
# - `is_repurchase`, `USER_KEY`, `is_promotion`, and payment indicator columns are excluded from features.
# - StratifiedKFold is used for comparability with existing PUBLIC notebooks. USER_KEY duplicate group leakage caveat remains.

# %%
from pathlib import Path
import json
import warnings

import numpy as np
import optuna
import pandas as pd
from sklearn.metrics import average_precision_score, f1_score, precision_score, recall_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.ensemble import GradientBoostingClassifier

warnings.filterwarnings("ignore", category=UserWarning)

ROOT = Path.cwd()
if not (ROOT / "PUBLIC").exists():
    ROOT = Path(r"C:\myCode\ott-churn-prediction")
PUBLIC = ROOT / "PUBLIC"

DATA = ROOT / "PUBLIC/data/06z_model_input_promo_0_log_retention_only.csv"
OUT_DIR = ROOT / "PUBLIC/results/_06z_log_retention_only_model_rerun_260520/gb_promo0"
PROMO = 0
MODEL_NAME = "GradientBoostingClassifier conservative"
RANDOM_STATE = 42
N_TRIALS = 100
N_SPLITS = 5
OVERFIT_GAP = 0.03
TEST_SIZE = 0.2
GAP_PENALTY = 0.50

TARGET_COL = "is_repurchase"
ID_COL = "USER_KEY"
RAW_RETENTION_COLS = ["retention_w2_ratio", "retention_w3_ratio"]
LOG_RETENTION_COLS = ["log_retention_w2_ratio", "log_retention_w3_ratio"]
EXCLUDE_COLS = [
    TARGET_COL,
    ID_COL,
    "is_promotion",
    "payment_is_mobile",
    "payment_is_pc",
    "payment_is_android",
    "payment_is_ios",
] + RAW_RETENTION_COLS

OUT_DIR.mkdir(parents=True, exist_ok=True)

df = pd.read_csv(DATA)
if any(col in df.columns for col in RAW_RETENTION_COLS):
    raise ValueError("Raw retention columns must not exist in log retention only model input.")
missing_log = [col for col in LOG_RETENTION_COLS if col not in df.columns]
if missing_log:
    raise ValueError(f"Missing log retention columns: {missing_log}")
if TARGET_COL not in df.columns:
    raise ValueError("Missing target column is_repurchase.")

feature_cols = [col for col in df.columns if col not in EXCLUDE_COLS]
non_numeric_cols = df[feature_cols].select_dtypes(exclude="number").columns.tolist()
if non_numeric_cols:
    raise ValueError(f"Non-numeric feature columns found: {non_numeric_cols}")
if not set(LOG_RETENTION_COLS).issubset(feature_cols):
    raise ValueError("Log retention columns are not included as features.")

X = df[feature_cols].copy()
y = pd.to_numeric(df[TARGET_COL], errors="raise").astype(int)
missing_total = int(X.isna().sum().sum())
if missing_total:
    X = X.fillna(X.median(numeric_only=True))

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y,
)

def make_model(params):
    return GradientBoostingClassifier(**params)

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 250),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.05),
        "max_depth": trial.suggest_int("max_depth", 1, 3),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 50, 300),
        "min_samples_split": trial.suggest_int("min_samples_split", 100, 600),
        "subsample": trial.suggest_float("subsample", 0.60, 0.90),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", None]),
        "random_state": RANDOM_STATE,
    }

    cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
    train_scores = []
    valid_scores = []
    for train_idx, valid_idx in cv.split(X_train, y_train):
        X_tr = X_train.iloc[train_idx]
        X_va = X_train.iloc[valid_idx]
        y_tr = y_train.iloc[train_idx]
        y_va = y_train.iloc[valid_idx]
        model = make_model(params)
        model.fit(X_tr, y_tr)
        train_pred = model.predict_proba(X_tr)[:, 1]
        valid_pred = model.predict_proba(X_va)[:, 1]
        train_scores.append(roc_auc_score(y_tr, train_pred))
        valid_scores.append(roc_auc_score(y_va, valid_pred))
    mean_train_auc = float(np.mean(train_scores))
    mean_valid_auc = float(np.mean(valid_scores))
    gap = mean_train_auc - mean_valid_auc
    objective_value = mean_valid_auc - GAP_PENALTY * max(0.0, gap)
    trial.set_user_attr("mean_train_auc", mean_train_auc)
    trial.set_user_attr("mean_valid_auc", mean_valid_auc)
    trial.set_user_attr("gap", gap)
    trial.set_user_attr("overfit", bool(gap > OVERFIT_GAP))
    trial.set_user_attr("objective_value", objective_value)
    return objective_value

study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
study.optimize(objective, n_trials=N_TRIALS)

trial_rows = []
for trial in study.trials:
    row = {
        "trial": trial.number,
        "objective_value": trial.user_attrs.get("objective_value"),
        "mean_valid_auc": trial.user_attrs.get("mean_valid_auc"),
        "mean_train_auc": trial.user_attrs.get("mean_train_auc"),
        "gap": trial.user_attrs.get("gap"),
        "overfit": trial.user_attrs.get("overfit"),
    }
    for key, value in trial.params.items():
        row[f"param_{key}"] = value
    trial_rows.append(row)
trials = pd.DataFrame(trial_rows)
trials.to_csv(OUT_DIR / "trials_all.csv", index=False, encoding="utf-8-sig")

eligible = trials[trials["overfit"].eq(False)].copy()
if eligible.empty:
    selected = trials.sort_values(["objective_value", "mean_valid_auc"], ascending=False).iloc[0]
    selection_note = "WARN: no non-overfit trial found"
else:
    selected = eligible.sort_values(["objective_value", "mean_valid_auc"], ascending=False).iloc[0]
    selection_note = "PASS: selected best non-overfit trial"

best_trial = study.trials[int(selected["trial"])]
best_params = best_trial.params
model = make_model(best_params)
model.fit(X_train, y_train)
test_proba = model.predict_proba(X_test)[:, 1]
test_pred = (test_proba >= 0.5).astype(int)
train_proba = model.predict_proba(X_train)[:, 1]

final_train_auc = roc_auc_score(y_train, train_proba)
test_roc_auc = roc_auc_score(y_test, test_proba)
test_pr_auc = average_precision_score(y_test, test_proba)

final = {
    "model": MODEL_NAME,
    "promo": PROMO,
    "data_file": str(DATA),
    "n_rows": len(df),
    "n_features": len(feature_cols),
    "n_trials": N_TRIALS,
    "best_trial": int(selected["trial"]),
    "gap_penalty": GAP_PENALTY,
    "best_objective_value": float(selected["objective_value"]),
    "best_valid_auc": float(selected["mean_valid_auc"]),
    "best_train_auc": float(selected["mean_train_auc"]),
    "best_gap": float(selected["gap"]),
    "overfit": bool(selected["overfit"]),
    "test_roc_auc": float(test_roc_auc),
    "test_pr_auc": float(test_pr_auc),
    "test_f1": float(f1_score(y_test, test_pred)),
    "test_precision": float(precision_score(y_test, test_pred, zero_division=0)),
    "test_recall": float(recall_score(y_test, test_pred, zero_division=0)),
    "final_train_auc": float(final_train_auc),
    "final_gap_proxy": float(final_train_auc - test_roc_auc),
    "selection_note": selection_note,
    "cv_method": "StratifiedKFold",
    "group_leakage_caveat": "USER_KEY can be duplicated. StratifiedKFold is retained for comparability with PUBLIC notebooks; GroupKFold was not used in this prepared notebook.",
    "raw_retention_removed": True,
    "log_retention_used": True,
}
for key, value in best_params.items():
    final[f"param_{key}"] = value
pd.DataFrame([final]).to_csv(OUT_DIR / "final_result.csv", index=False, encoding="utf-8-sig")

feature_manifest = pd.DataFrame({
    "feature_name": feature_cols,
    "used_as_feature": True,
})
feature_manifest.to_csv(OUT_DIR / "feature_manifest_used.csv", index=False, encoding="utf-8-sig")

print(json.dumps(final, ensure_ascii=False, indent=2))
# Out:
# [I 2026-05-20 14:53:31,134] A new study created in memory with name: no-name-aa0866f1-bdcb-41f2-ac96-80c393dcad2c
# [I 2026-05-20 14:53:45,827] Trial 0 finished with value: 0.8675320561413415 and parameters: {'n_estimators': 125, 'learning_rate': 0.04802857225639665, 'max_depth': 3, 'min_samples_leaf': 200, 'min_samples_split': 178, 'subsample': 0.6467983561008608, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:53:53,154] Trial 1 finished with value: 0.8377060988415005 and parameters: {'n_estimators': 170, 'learning_rate': 0.03832290311184182, 'max_depth': 1, 'min_samples_leaf': 293, 'min_samples_split': 517, 'subsample': 0.6637017332034828, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:54:02,146] Trial 2 finished with value: 0.8473854114078321 and parameters: {'n_estimators': 111, 'learning_rate': 0.030990257265289513, 'max_depth': 2, 'min_samples_leaf': 123, 'min_samples_split': 406, 'subsample': 0.6418481581956126, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:54:03,483] Trial 3 finished with value: 0.8247087880312827 and parameters: {'n_estimators': 141, 'learning_rate': 0.041407038455720545, 'max_depth': 1, 'min_samples_leaf': 179, 'min_samples_split': 396, 'subsample': 0.6139351238159994, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:54:04,688] Trial 4 finished with value: 0.8486902208790352 and parameters: {'n_estimators': 63, 'learning_rate': 0.047955421490133335, 'max_depth': 3, 'min_samples_leaf': 252, 'min_samples_split': 252, 'subsample': 0.6293016342019151, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:54:09,872] Trial 5 finished with value: 0.8004659384978732 and parameters: {'n_estimators': 74, 'learning_rate': 0.029807076404450808, 'max_depth': 1, 'min_samples_leaf': 278, 'min_samples_split': 229, 'subsample': 0.7987566853061946, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:54:41,203] Trial 6 finished with value: 0.8542677519960907 and parameters: {'n_estimators': 159, 'learning_rate': 0.017394178221021083, 'max_depth': 3, 'min_samples_leaf': 244, 'min_samples_split': 570, 'subsample': 0.8684482051282947, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:54:42,004] Trial 7 finished with value: 0.7850887972755127 and parameters: {'n_estimators': 67, 'learning_rate': 0.017839314496765808, 'max_depth': 1, 'min_samples_leaf': 131, 'min_samples_split': 294, 'subsample': 0.6814047095321688, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:54:43,339] Trial 8 finished with value: 0.8031230012870287 and parameters: {'n_estimators': 106, 'learning_rate': 0.03170784332632994, 'max_depth': 1, 'min_samples_leaf': 251, 'min_samples_split': 137, 'subsample': 0.8960660809801553, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:54:44,469] Trial 9 finished with value: 0.8430551201953016 and parameters: {'n_estimators': 51, 'learning_rate': 0.04261845713819337, 'max_depth': 3, 'min_samples_leaf': 232, 'min_samples_split': 486, 'subsample': 0.6222133955202271, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:55:09,953] Trial 10 finished with value: 0.8382304404738703 and parameters: {'n_estimators': 230, 'learning_rate': 0.010239887318232686, 'max_depth': 2, 'min_samples_leaf': 54, 'min_samples_split': 107, 'subsample': 0.7314242782385489, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:55:40,409] Trial 11 finished with value: 0.8615873852915796 and parameters: {'n_estimators': 182, 'learning_rate': 0.02058834880064951, 'max_depth': 3, 'min_samples_leaf': 184, 'min_samples_split': 573, 'subsample': 0.8394815118118929, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:56:12,523] Trial 12 finished with value: 0.8644545742926621 and parameters: {'n_estimators': 204, 'learning_rate': 0.023125994111743823, 'max_depth': 3, 'min_samples_leaf': 186, 'min_samples_split': 179, 'subsample': 0.8036844194695725, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:56:36,594] Trial 13 finished with value: 0.8601639635182303 and parameters: {'n_estimators': 223, 'learning_rate': 0.025947161289798598, 'max_depth': 2, 'min_samples_leaf': 207, 'min_samples_split': 196, 'subsample': 0.7551004042955007, 'max_features': None}. Best is trial 0 with value: 0.8675320561413415.
# [I 2026-05-20 14:57:05,204] Trial 14 finished with value: 0.869071506102223 and parameters: {'n_estimators': 185, 'learning_rate': 0.04968053059265035, 'max_depth': 3, 'min_samples_leaf': 143, 'min_samples_split': 169, 'subsample': 0.7220648662649468, 'max_features': None}. Best is trial 14 with value: 0.869071506102223.
# [I 2026-05-20 14:57:25,359] Trial 15 finished with value: 0.8677408158248745 and parameters: {'n_estimators': 130, 'learning_rate': 0.04948042556366502, 'max_depth': 3, 'min_samples_leaf': 110, 'min_samples_split': 308, 'subsample': 0.7102136661660048, 'max_features': None}. Best is trial 14 with value: 0.869071506102223.
# [I 2026-05-20 14:57:46,405] Trial 16 finished with value: 0.8690958532229924 and parameters: {'n_estimators': 203, 'learning_rate': 0.049606231361598634, 'max_depth': 2, 'min_samples_leaf': 115, 'min_samples_split': 323, 'subsample': 0.713220788288819, 'max_features': None}. Best is trial 16 with value: 0.8690958532229924.
# [I 2026-05-20 14:58:08,514] Trial 17 finished with value: 0.8643986950320239 and parameters: {'n_estimators': 195, 'learning_rate': 0.03846813626083054, 'max_depth': 2, 'min_samples_leaf': 85, 'min_samples_split': 349, 'subsample': 0.7642237682531265, 'max_features': None}. Best is trial 16 with value: 0.8690958532229924.
# [I 2026-05-20 14:58:33,615] Trial 18 finished with value: 0.869815119601232 and parameters: {'n_estimators': 246, 'learning_rate': 0.04360060668358781, 'max_depth': 2, 'min_samples_leaf': 148, 'min_samples_split': 429, 'subsample': 0.6978312384395814, 'max_features': None}. Best is trial 18 with value: 0.869815119601232.
# [I 2026-05-20 14:58:59,626] Trial 19 finished with value: 0.8705174308617016 and parameters: {'n_estimators': 248, 'learning_rate': 0.04376560608093201, 'max_depth': 2, 'min_samples_leaf': 152, 'min_samples_split': 445, 'subsample': 0.6924421537333716, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 14:59:24,913] Trial 20 finished with value: 0.8674444631834222 and parameters: {'n_estimators': 250, 'learning_rate': 0.03523262026454018, 'max_depth': 2, 'min_samples_leaf': 150, 'min_samples_split': 426, 'subsample': 0.6671109287982315, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 14:59:51,546] Trial 21 finished with value: 0.8703476041163999 and parameters: {'n_estimators': 249, 'learning_rate': 0.04308805901316675, 'max_depth': 2, 'min_samples_leaf': 94, 'min_samples_split': 463, 'subsample': 0.6996435529265221, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:00:17,747] Trial 22 finished with value: 0.8704721921765595 and parameters: {'n_estimators': 249, 'learning_rate': 0.044065689194562024, 'max_depth': 2, 'min_samples_leaf': 84, 'min_samples_split': 472, 'subsample': 0.6936227681156298, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:00:40,546] Trial 23 finished with value: 0.8688486499558172 and parameters: {'n_estimators': 226, 'learning_rate': 0.043550544106256174, 'max_depth': 2, 'min_samples_leaf': 68, 'min_samples_split': 479, 'subsample': 0.6805332952441572, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:01:05,251] Trial 24 finished with value: 0.8682126172554145 and parameters: {'n_estimators': 236, 'learning_rate': 0.03834563848809288, 'max_depth': 2, 'min_samples_leaf': 89, 'min_samples_split': 521, 'subsample': 0.7395360863812563, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:01:28,792] Trial 25 finished with value: 0.8687534089281544 and parameters: {'n_estimators': 218, 'learning_rate': 0.045640721881935124, 'max_depth': 2, 'min_samples_leaf': 94, 'min_samples_split': 464, 'subsample': 0.7740391423749113, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:01:32,787] Trial 26 finished with value: 0.8643948182577288 and parameters: {'n_estimators': 249, 'learning_rate': 0.03613478405743212, 'max_depth': 2, 'min_samples_leaf': 52, 'min_samples_split': 532, 'subsample': 0.6844659489730096, 'max_features': 'sqrt'}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:01:51,820] Trial 27 finished with value: 0.8693195312186335 and parameters: {'n_estimators': 215, 'learning_rate': 0.04615334073317669, 'max_depth': 2, 'min_samples_leaf': 160, 'min_samples_split': 377, 'subsample': 0.604318176087983, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:02:13,769] Trial 28 finished with value: 0.868543818284967 and parameters: {'n_estimators': 237, 'learning_rate': 0.04118796863783699, 'max_depth': 2, 'min_samples_leaf': 104, 'min_samples_split': 449, 'subsample': 0.6557635386421155, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:02:25,669] Trial 29 finished with value: 0.843054181819586 and parameters: {'n_estimators': 212, 'learning_rate': 0.034440885941974295, 'max_depth': 1, 'min_samples_leaf': 74, 'min_samples_split': 366, 'subsample': 0.7053835860660942, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:02:51,918] Trial 30 finished with value: 0.8700119433596779 and parameters: {'n_estimators': 239, 'learning_rate': 0.04547786478474576, 'max_depth': 2, 'min_samples_leaf': 131, 'min_samples_split': 499, 'subsample': 0.7821993132129289, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:03:20,085] Trial 31 finished with value: 0.8696174715919327 and parameters: {'n_estimators': 236, 'learning_rate': 0.045981421026131855, 'max_depth': 2, 'min_samples_leaf': 129, 'min_samples_split': 496, 'subsample': 0.8079051154083517, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:03:47,188] Trial 32 finished with value: 0.8689635141396961 and parameters: {'n_estimators': 238, 'learning_rate': 0.04058169882381758, 'max_depth': 2, 'min_samples_leaf': 160, 'min_samples_split': 552, 'subsample': 0.7787696339158364, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:04:13,991] Trial 33 finished with value: 0.8689200601340066 and parameters: {'n_estimators': 246, 'learning_rate': 0.039701797767029756, 'max_depth': 2, 'min_samples_leaf': 105, 'min_samples_split': 506, 'subsample': 0.7381320115103012, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:04:37,212] Trial 34 finished with value: 0.8694616418905597 and parameters: {'n_estimators': 224, 'learning_rate': 0.04430262141952825, 'max_depth': 2, 'min_samples_leaf': 133, 'min_samples_split': 441, 'subsample': 0.6916195934184751, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:04:53,799] Trial 35 finished with value: 0.866047665316404 and parameters: {'n_estimators': 173, 'learning_rate': 0.046915575734648156, 'max_depth': 2, 'min_samples_leaf': 74, 'min_samples_split': 598, 'subsample': 0.6434917981268032, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:04:56,047] Trial 36 finished with value: 0.830590505399042 and parameters: {'n_estimators': 204, 'learning_rate': 0.032789344502277995, 'max_depth': 1, 'min_samples_leaf': 167, 'min_samples_split': 410, 'subsample': 0.6656460424932642, 'max_features': 'sqrt'}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:05:14,732] Trial 37 finished with value: 0.8599641766285977 and parameters: {'n_estimators': 155, 'learning_rate': 0.036864962951109935, 'max_depth': 2, 'min_samples_leaf': 207, 'min_samples_split': 465, 'subsample': 0.8310378796555137, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:05:19,909] Trial 38 finished with value: 0.8044880393913065 and parameters: {'n_estimators': 89, 'learning_rate': 0.028368233773906147, 'max_depth': 1, 'min_samples_leaf': 118, 'min_samples_split': 389, 'subsample': 0.7852288566689797, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:05:23,479] Trial 39 finished with value: 0.8652102396312187 and parameters: {'n_estimators': 233, 'learning_rate': 0.04212499070555411, 'max_depth': 2, 'min_samples_leaf': 99, 'min_samples_split': 530, 'subsample': 0.6360742880394992, 'max_features': 'sqrt'}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:05:44,240] Trial 40 finished with value: 0.8669170915009676 and parameters: {'n_estimators': 194, 'learning_rate': 0.044855856344647387, 'max_depth': 2, 'min_samples_leaf': 140, 'min_samples_split': 414, 'subsample': 0.7552611627852327, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:06:09,469] Trial 41 finished with value: 0.8701146224274143 and parameters: {'n_estimators': 250, 'learning_rate': 0.04336665916469039, 'max_depth': 2, 'min_samples_leaf': 151, 'min_samples_split': 439, 'subsample': 0.698185035765243, 'max_features': None}. Best is trial 19 with value: 0.8705174308617016.
# [I 2026-05-20 15:06:34,361] Trial 42 finished with value: 0.870988439766998 and parameters: {'n_estimators': 242, 'learning_rate': 0.04779076003288725, 'max_depth': 2, 'min_samples_leaf': 124, 'min_samples_split': 455, 'subsample': 0.7205463659562059, 'max_features': None}. Best is trial 42 with value: 0.870988439766998.
# [I 2026-05-20 15:07:00,824] Trial 43 finished with value: 0.8710311540221621 and parameters: {'n_estimators': 248, 'learning_rate': 0.04762378419247988, 'max_depth': 2, 'min_samples_leaf': 119, 'min_samples_split': 457, 'subsample': 0.7220276290204236, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:07:25,405] Trial 44 finished with value: 0.8700054467541194 and parameters: {'n_estimators': 226, 'learning_rate': 0.04730935734585016, 'max_depth': 2, 'min_samples_leaf': 118, 'min_samples_split': 483, 'subsample': 0.7201962805449689, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:07:28,969] Trial 45 finished with value: 0.865169518510243 and parameters: {'n_estimators': 211, 'learning_rate': 0.04817309311080135, 'max_depth': 2, 'min_samples_leaf': 84, 'min_samples_split': 459, 'subsample': 0.6738204844056626, 'max_features': 'sqrt'}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:07:37,205] Trial 46 finished with value: 0.8406779632374376 and parameters: {'n_estimators': 143, 'learning_rate': 0.04794589348016615, 'max_depth': 1, 'min_samples_leaf': 60, 'min_samples_split': 400, 'subsample': 0.7301426930832732, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:08:08,334] Trial 47 finished with value: 0.8699181132833544 and parameters: {'n_estimators': 242, 'learning_rate': 0.04182037767359859, 'max_depth': 3, 'min_samples_leaf': 276, 'min_samples_split': 552, 'subsample': 0.6541791160540191, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:08:33,936] Trial 48 finished with value: 0.8456897228575848 and parameters: {'n_estimators': 230, 'learning_rate': 0.013574143511374467, 'max_depth': 2, 'min_samples_leaf': 194, 'min_samples_split': 351, 'subsample': 0.7399618537532139, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:08:45,244] Trial 49 finished with value: 0.8600817212848131 and parameters: {'n_estimators': 110, 'learning_rate': 0.0499168867209288, 'max_depth': 2, 'min_samples_leaf': 125, 'min_samples_split': 259, 'subsample': 0.7139407146152051, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:08:50,256] Trial 50 finished with value: 0.8684801145620378 and parameters: {'n_estimators': 222, 'learning_rate': 0.03957012505354617, 'max_depth': 3, 'min_samples_leaf': 79, 'min_samples_split': 472, 'subsample': 0.6914725575141865, 'max_features': 'sqrt'}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:09:15,703] Trial 51 finished with value: 0.8700976921495518 and parameters: {'n_estimators': 249, 'learning_rate': 0.04346618217862556, 'max_depth': 2, 'min_samples_leaf': 174, 'min_samples_split': 440, 'subsample': 0.7011206677200833, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:09:41,423] Trial 52 finished with value: 0.8703520229111115 and parameters: {'n_estimators': 242, 'learning_rate': 0.04789777958553201, 'max_depth': 2, 'min_samples_leaf': 153, 'min_samples_split': 431, 'subsample': 0.7230860864735386, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:10:07,136] Trial 53 finished with value: 0.8699521811056632 and parameters: {'n_estimators': 240, 'learning_rate': 0.04815867877207148, 'max_depth': 2, 'min_samples_leaf': 138, 'min_samples_split': 415, 'subsample': 0.7262709992433155, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:10:32,126] Trial 54 finished with value: 0.8699392976732122 and parameters: {'n_estimators': 230, 'learning_rate': 0.04824834976206399, 'max_depth': 2, 'min_samples_leaf': 111, 'min_samples_split': 508, 'subsample': 0.7487506581404502, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:10:58,070] Trial 55 finished with value: 0.8704361402588923 and parameters: {'n_estimators': 242, 'learning_rate': 0.04484556299441144, 'max_depth': 2, 'min_samples_leaf': 98, 'min_samples_split': 392, 'subsample': 0.7152052780542766, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:11:11,236] Trial 56 finished with value: 0.8603778377501212 and parameters: {'n_estimators': 124, 'learning_rate': 0.04693033610839782, 'max_depth': 2, 'min_samples_leaf': 162, 'min_samples_split': 385, 'subsample': 0.7148504223165575, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:11:32,993] Trial 57 finished with value: 0.8688612641753328 and parameters: {'n_estimators': 217, 'learning_rate': 0.045008333722331775, 'max_depth': 2, 'min_samples_leaf': 122, 'min_samples_split': 322, 'subsample': 0.6793773236934751, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:11:56,118] Trial 58 finished with value: 0.8703639823042089 and parameters: {'n_estimators': 230, 'learning_rate': 0.048781201499061684, 'max_depth': 2, 'min_samples_leaf': 146, 'min_samples_split': 361, 'subsample': 0.7489158966376279, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:12:15,579] Trial 59 finished with value: 0.8682454511297638 and parameters: {'n_estimators': 195, 'learning_rate': 0.0499375375805707, 'max_depth': 2, 'min_samples_leaf': 65, 'min_samples_split': 355, 'subsample': 0.763098699364076, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:12:38,183] Trial 60 finished with value: 0.8682447073352708 and parameters: {'n_estimators': 233, 'learning_rate': 0.04050949106083988, 'max_depth': 2, 'min_samples_leaf': 108, 'min_samples_split': 272, 'subsample': 0.74608804770623, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:13:00,932] Trial 61 finished with value: 0.8706287188293851 and parameters: {'n_estimators': 242, 'learning_rate': 0.04649587665974196, 'max_depth': 2, 'min_samples_leaf': 153, 'min_samples_split': 327, 'subsample': 0.7249631409207757, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:13:24,124] Trial 62 finished with value: 0.8701871307024047 and parameters: {'n_estimators': 241, 'learning_rate': 0.046320559960981535, 'max_depth': 2, 'min_samples_leaf': 173, 'min_samples_split': 325, 'subsample': 0.73151672719235, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:13:45,630] Trial 63 finished with value: 0.8698340949142117 and parameters: {'n_estimators': 229, 'learning_rate': 0.04447030949289212, 'max_depth': 2, 'min_samples_leaf': 138, 'min_samples_split': 399, 'subsample': 0.7074727309891743, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:14:07,225] Trial 64 finished with value: 0.8700548131484447 and parameters: {'n_estimators': 221, 'learning_rate': 0.048844979492142136, 'max_depth': 2, 'min_samples_leaf': 146, 'min_samples_split': 301, 'subsample': 0.7539688127048076, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:14:26,226] Trial 65 finished with value: 0.8677282478434033 and parameters: {'n_estimators': 207, 'learning_rate': 0.042064890924371864, 'max_depth': 2, 'min_samples_leaf': 155, 'min_samples_split': 336, 'subsample': 0.6899010002804224, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:14:50,310] Trial 66 finished with value: 0.8696418309285752 and parameters: {'n_estimators': 244, 'learning_rate': 0.04628316680586715, 'max_depth': 2, 'min_samples_leaf': 98, 'min_samples_split': 454, 'subsample': 0.7638696527593511, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:15:11,897] Trial 67 finished with value: 0.8602645263989426 and parameters: {'n_estimators': 234, 'learning_rate': 0.02467741877773052, 'max_depth': 2, 'min_samples_leaf': 180, 'min_samples_split': 374, 'subsample': 0.7351961511984338, 'max_features': None}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:15:15,732] Trial 68 finished with value: 0.8672119274245564 and parameters: {'n_estimators': 250, 'learning_rate': 0.04458677197502112, 'max_depth': 2, 'min_samples_leaf': 90, 'min_samples_split': 365, 'subsample': 0.7150997558494441, 'max_features': 'sqrt'}. Best is trial 43 with value: 0.8710311540221621.
# [I 2026-05-20 15:15:38,113] Trial 69 finished with value: 0.871155689419824 and parameters: {'n_estimators': 243, 'learning_rate': 0.046978442305793414, 'max_depth': 2, 'min_samples_leaf': 189, 'min_samples_split': 423, 'subsample': 0.70555939785413, 'max_features': None}. Best is trial 69 with value: 0.871155689419824.
# [I 2026-05-20 15:15:58,518] Trial 70 finished with value: 0.870149666133575 and parameters: {'n_estimators': 244, 'learning_rate': 0.042833857981064274, 'max_depth': 2, 'min_samples_leaf': 204, 'min_samples_split': 427, 'subsample': 0.6727185906409213, 'max_features': None}. Best is trial 69 with value: 0.871155689419824.
# [I 2026-05-20 15:16:19,639] Trial 71 finished with value: 0.870660468121567 and parameters: {'n_estimators': 238, 'learning_rate': 0.04690345489489072, 'max_depth': 2, 'min_samples_leaf': 165, 'min_samples_split': 491, 'subsample': 0.7058137882186264, 'max_features': None}. Best is trial 69 with value: 0.871155689419824.
# [I 2026-05-20 15:16:40,732] Trial 72 finished with value: 0.8705813168995534 and parameters: {'n_estimators': 237, 'learning_rate': 0.04552214914469555, 'max_depth': 2, 'min_samples_leaf': 197, 'min_samples_split': 496, 'subsample': 0.7030553738418113, 'max_features': None}. Best is trial 69 with value: 0.871155689419824.
# [I 2026-05-20 15:17:00,955] Trial 73 finished with value: 0.8700772629765992 and parameters: {'n_estimators': 236, 'learning_rate': 0.046293150760058764, 'max_depth': 2, 'min_samples_leaf': 219, 'min_samples_split': 496, 'subsample': 0.702793973462956, 'max_features': None}. Best is trial 69 with value: 0.871155689419824.
# [I 2026-05-20 15:17:19,922] Trial 74 finished with value: 0.8698275403841993 and parameters: {'n_estimators': 219, 'learning_rate': 0.047185191733534936, 'max_depth': 2, 'min_samples_leaf': 196, 'min_samples_split': 517, 'subsample': 0.6918912149593615, 'max_features': None}. Best is trial 69 with value: 0.871155689419824.
# [I 2026-05-20 15:17:41,245] Trial 75 finished with value: 0.8694263336084258 and parameters: {'n_estimators': 237, 'learning_rate': 0.04565099424480513, 'max_depth': 2, 'min_samples_leaf': 182, 'min_samples_split': 549, 'subsample': 0.6612627503955553, 'max_features': None}. Best is trial 69 with value: 0.871155689419824.
# [I 2026-05-20 15:18:04,288] Trial 76 finished with value: 0.8693883479017079 and parameters: {'n_estimators': 227, 'learning_rate': 0.04366710476788525, 'max_depth': 2, 'min_samples_leaf': 214, 'min_samples_split': 481, 'subsample': 0.682670405861358, 'max_features': None}. Best is trial 69 with value: 0.871155689419824.
# [I 2026-05-20 15:18:30,589] Trial 77 finished with value: 0.8714292304466175 and parameters: {'n_estimators': 246, 'learning_rate': 0.048976290351863176, 'max_depth': 2, 'min_samples_leaf': 189, 'min_samples_split': 473, 'subsample': 0.7083989692888751, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:18:53,887] Trial 78 finished with value: 0.8695650128578247 and parameters: {'n_estimators': 211, 'learning_rate': 0.04917132431611467, 'max_depth': 2, 'min_samples_leaf': 194, 'min_samples_split': 490, 'subsample': 0.7066418330990241, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:19:12,233] Trial 79 finished with value: 0.8661531735613446 and parameters: {'n_estimators': 164, 'learning_rate': 0.047160080409510176, 'max_depth': 2, 'min_samples_leaf': 228, 'min_samples_split': 524, 'subsample': 0.7253160853277123, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:19:14,034] Trial 80 finished with value: 0.8179365854064373 and parameters: {'n_estimators': 98, 'learning_rate': 0.018609629518197224, 'max_depth': 2, 'min_samples_leaf': 188, 'min_samples_split': 541, 'subsample': 0.7207378720860084, 'max_features': 'sqrt'}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:19:39,229] Trial 81 finished with value: 0.8703594595004019 and parameters: {'n_estimators': 246, 'learning_rate': 0.04576141958198493, 'max_depth': 2, 'min_samples_leaf': 169, 'min_samples_split': 452, 'subsample': 0.6978727405106891, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:20:02,592] Trial 82 finished with value: 0.8707123479074921 and parameters: {'n_estimators': 238, 'learning_rate': 0.0490236383781687, 'max_depth': 2, 'min_samples_leaf': 187, 'min_samples_split': 468, 'subsample': 0.6854841286727613, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:20:25,900] Trial 83 finished with value: 0.8705326837021037 and parameters: {'n_estimators': 235, 'learning_rate': 0.04900504284121121, 'max_depth': 2, 'min_samples_leaf': 186, 'min_samples_split': 472, 'subsample': 0.6866862377253852, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:20:49,195] Trial 84 finished with value: 0.8698345681464881 and parameters: {'n_estimators': 225, 'learning_rate': 0.04904046477561798, 'max_depth': 2, 'min_samples_leaf': 188, 'min_samples_split': 509, 'subsample': 0.6752252439280334, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:21:12,920] Trial 85 finished with value: 0.8700695299922251 and parameters: {'n_estimators': 234, 'learning_rate': 0.04745191753098134, 'max_depth': 2, 'min_samples_leaf': 212, 'min_samples_split': 466, 'subsample': 0.6858588108092358, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:21:38,074] Trial 86 finished with value: 0.8704735845655456 and parameters: {'n_estimators': 240, 'learning_rate': 0.04883039701073089, 'max_depth': 2, 'min_samples_leaf': 166, 'min_samples_split': 478, 'subsample': 0.7084142824803487, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:22:02,316] Trial 87 finished with value: 0.8701682140286858 and parameters: {'n_estimators': 244, 'learning_rate': 0.046613758178931514, 'max_depth': 2, 'min_samples_leaf': 198, 'min_samples_split': 498, 'subsample': 0.6698594037608762, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:22:31,125] Trial 88 finished with value: 0.8701922679398493 and parameters: {'n_estimators': 232, 'learning_rate': 0.049407066951175624, 'max_depth': 2, 'min_samples_leaf': 179, 'min_samples_split': 574, 'subsample': 0.8862988210836256, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:22:37,341] Trial 89 finished with value: 0.8401210616195963 and parameters: {'n_estimators': 56, 'learning_rate': 0.0481064843439312, 'max_depth': 2, 'min_samples_leaf': 187, 'min_samples_split': 486, 'subsample': 0.7410141453691174, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:23:03,178] Trial 90 finished with value: 0.8701197006000853 and parameters: {'n_estimators': 222, 'learning_rate': 0.049831548722262156, 'max_depth': 2, 'min_samples_leaf': 204, 'min_samples_split': 421, 'subsample': 0.7314174372671668, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:23:31,148] Trial 91 finished with value: 0.8705769409754214 and parameters: {'n_estimators': 250, 'learning_rate': 0.04555788146814763, 'max_depth': 2, 'min_samples_leaf': 172, 'min_samples_split': 444, 'subsample': 0.6952764953848675, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:23:55,792] Trial 92 finished with value: 0.870635303089967 and parameters: {'n_estimators': 246, 'learning_rate': 0.04541194227141553, 'max_depth': 2, 'min_samples_leaf': 175, 'min_samples_split': 446, 'subsample': 0.6969027807058795, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:24:21,712] Trial 93 finished with value: 0.8703293794550023 and parameters: {'n_estimators': 245, 'learning_rate': 0.04539445846803413, 'max_depth': 2, 'min_samples_leaf': 175, 'min_samples_split': 458, 'subsample': 0.6978814249475722, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:24:50,140] Trial 94 finished with value: 0.871387111565664 and parameters: {'n_estimators': 250, 'learning_rate': 0.047447214832812536, 'max_depth': 2, 'min_samples_leaf': 158, 'min_samples_split': 434, 'subsample': 0.711438143527365, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:25:17,349] Trial 95 finished with value: 0.87044635483504 and parameters: {'n_estimators': 238, 'learning_rate': 0.04742396787147439, 'max_depth': 2, 'min_samples_leaf': 158, 'min_samples_split': 433, 'subsample': 0.7172676762370618, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:25:42,472] Trial 96 finished with value: 0.870097147876208 and parameters: {'n_estimators': 245, 'learning_rate': 0.0443043840394302, 'max_depth': 2, 'min_samples_leaf': 165, 'min_samples_split': 409, 'subsample': 0.7066961239604979, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:26:08,106] Trial 97 finished with value: 0.8707033968240688 and parameters: {'n_estimators': 239, 'learning_rate': 0.046896828952543254, 'max_depth': 2, 'min_samples_leaf': 193, 'min_samples_split': 284, 'subsample': 0.7240228577207874, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:26:34,278] Trial 98 finished with value: 0.8699211608517423 and parameters: {'n_estimators': 228, 'learning_rate': 0.04791971799582338, 'max_depth': 2, 'min_samples_leaf': 192, 'min_samples_split': 310, 'subsample': 0.7330483691804253, 'max_features': None}. Best is trial 77 with value: 0.8714292304466175.
# [I 2026-05-20 15:26:38,418] Trial 99 finished with value: 0.8640612465696018 and parameters: {'n_estimators': 214, 'learning_rate': 0.042703578914098025, 'max_depth': 2, 'min_samples_leaf': 180, 'min_samples_split': 288, 'subsample': 0.7199646381675089, 'max_features': 'sqrt'}. Best is trial 77 with value: 0.8714292304466175.
# {
#   "model": "GradientBoostingClassifier conservative",
#   "promo": 0,
#   "data_file": "C:\\myCode\\ott-churn-prediction\\PUBLIC\\data\\06z_model_input_promo_0_log_retention_only.csv",
#   "n_rows": 11193,
#   "n_features": 75,
#   "n_trials": 100,
#   "best_trial": 77,
#   "gap_penalty": 0.5,
#   "best_objective_value": 0.8714292304466175,
#   "best_valid_auc": 0.8797003027632948,
#   "best_train_auc": 0.8962424473966495,
#   "best_gap": 0.016542144633354683,
#   "overfit": false,
#   "test_roc_auc": 0.8826900770496213,
#   "test_pr_auc": 0.9572137323177481,
#   "test_f1": 0.8923943661971832,
#   "test_precision": 0.8599348534201955,
#   "test_recall": 0.927400468384075,
#   "final_train_auc": 0.8946081848173447,
#   "final_gap_proxy": 0.011918107767723396,
#   "selection_note": "PASS: selected best non-overfit trial",
#   "cv_method": "StratifiedKFold",
#   "group_leakage_caveat": "USER_KEY can be duplicated. StratifiedKFold is retained for comparability with PUBLIC notebooks; GroupKFold was not used in this prepared notebook.",
#   "raw_retention_removed": true,
#   "log_retention_used": true,
#   "param_n_estimators": 246,
#   "param_learning_rate": 0.048976290351863176,
#   "param_max_depth": 2,
#   "param_min_samples_leaf": 189,
#   "param_min_samples_split": 473,
#   "param_subsample": 0.7083989692888751,
#   "param_max_features": null
# }
